# %%
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# Import a bunch of libraries.
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib.ticker import MultipleLocator
from sklearn.pipeline import Pipeline
from sklearn.datasets import fetch_mldata
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report

import csv

# Set the randomizer seed so results are the same each time.
np.random.seed(0)

# %%
data_directory = '../data/'
training_csv = 'training.csv'
test_csv = 'test.csv'

def space_separated_string_to_numpy_array(string):
    return np.fromstring(string, dtype=int, sep=" ")

def read_data_as_data_frame_with_image_array(data_directory, csv):
    return pd.read_csv(data_directory + csv, converters = { 
        'Image' : space_separated_string_to_numpy_array
    })

raw_training_data = pd.read_csv(data_directory + training_csv)
raw_test_data = pd.read_csv(data_directory + test_csv)

# %%
np.shape(raw_training_data)
# Out:
# (7049, 31)

# %%
raw_training_data
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0             66.033564          39.002274           30.227008
# 1             64.332936          34.970077           29.949277
# 2             65.057053          34.909642           30.903789
# 3             65.225739          37.261774           32.023096
# 4             66.725301          39.621261           32.244810
# 5             69.680748          39.968748           29.183551
# 6             64.131866          34.290040           29.578953
# 7             67.468893          39.413452           29.355961
# 8             65.802880          34.755200           27.475840
# 9             64.121231          36.740308           29.468923
# 10            65.230189          34.342642           28.802717
# 11            66.737600          39.886400           30.270400
# 12            66.574737          37.308000           30.445263
# 13            65.270588          34.940235           33.022745
# ...

# %%
raw_test_data
# Out:
#       ImageId                                              Image
# 0           1  182 183 182 182 180 180 176 169 156 137 124 10...
# 1           2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 2           3  177 176 174 170 169 169 168 166 166 166 161 14...
# 3           4  176 174 174 175 174 174 176 176 175 171 165 15...
# 4           5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...
# 5           6  177 177 177 171 142 115 97 84 89 90 88 82 63 5...
# 6           7  77 55 44 56 58 61 67 66 65 65 65 73 72 78 86 9...
# 7           8  156 160 162 166 150 114 97 105 125 127 119 121...
# 8           9  230 230 231 231 231 231 231 231 231 229 214 20...
# 9          10  132 129 126 128 146 163 170 169 143 101 71 55 ...
# 10         11  182 182 182 182 182 181 183 183 182 181 183 18...
# 11         12  207 205 204 202 205 197 184 179 179 176 189 19...
# 12         13  121 83 58 41 37 36 33 33 37 37 37 37 35 40 39 ...
# ...

# %%
def space_separated_string_to_numpy_array(string):
    return np.fromstring(string, dtype=int, sep=" ")

test_data = pd.read_csv(data_directory + test_csv, converters = { 
        'Image' : space_separated_string_to_numpy_array
})

# %%
test_data
# Out:
#       ImageId                                              Image
# 0           1  [182, 183, 182, 182, 180, 180, 176, 169, 156, ...
# 1           2  [76, 87, 81, 72, 65, 59, 64, 76, 69, 42, 31, 3...
# 2           3  [177, 176, 174, 170, 169, 169, 168, 166, 166, ...
# 3           4  [176, 174, 174, 175, 174, 174, 176, 176, 175, ...
# 4           5  [50, 47, 44, 101, 144, 149, 120, 58, 48, 42, 3...
# 5           6  [177, 177, 177, 171, 142, 115, 97, 84, 89, 90,...
# 6           7  [77, 55, 44, 56, 58, 61, 67, 66, 65, 65, 65, 7...
# 7           8  [156, 160, 162, 166, 150, 114, 97, 105, 125, 1...
# 8           9  [230, 230, 231, 231, 231, 231, 231, 231, 231, ...
# 9          10  [132, 129, 126, 128, 146, 163, 170, 169, 143, ...
# 10         11  [182, 182, 182, 182, 182, 181, 183, 183, 182, ...
# 11         12  [207, 205, 204, 202, 205, 197, 184, 179, 179, ...
# 12         13  [121, 83, 58, 41, 37, 36, 33, 33, 37, 37, 37, ...
# ...
